# %% [markdown]
# <a href="https://colab.research.google.com/github/M-coder-web-cell/llm-engineering/blob/master/huggingface/HandsOn_Quantization_lowlevel_HF_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files, userdata
from huggingface_hub import login
import torch

# %%
# !pip install -q --upgrade bitsandbytes accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 11.8 MB/s eta 0:00:00

# %%
hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential = True)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, TextStreamer, BitsAndBytesConfig

# %%
QWEN = 'Qwen/Qwen3-4B-Instruct-2507'

# %%
messages = [{
    "role" : "user", "content" : "Tell a joke for a room full of data scientists"
}]

# %% [markdown]
# ##Models
# ####Looking at the lower level api of models to locally host a smaller model using quantization Techniques

# %%
quant_config = BitsAndBytesConfig(
    load_in_4bit = True,
    bnb_4bit_use_double_quant = True,
    bnb_4bit_compute_dtype = torch.bfloat16,
    bnb_4bit_quant_type = "fn4"
)
