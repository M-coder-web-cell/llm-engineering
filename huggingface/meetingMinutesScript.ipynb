# %% [markdown]
# <a href="https://colab.research.google.com/github/M-coder-web-cell/llm-engineering/blob/master/huggingface/meetingMinutesScript.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
